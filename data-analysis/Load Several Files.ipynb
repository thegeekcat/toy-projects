# %%
import glob
import pandas as pd

# %%
path = './data/데이터랩 - 방문자수 - 덕진/'

# %%
file_list = glob.glob(path + '\\*.csv')
for file in file_list:
    current_data = pd.read_csv(file, encoding='cp949')
    print(current_data)
# Out:
#       기준연월            지역명      방문자 수
# 0   201802  전라북도 전주시 덕진구   2604906.0
# 1   201804  전라북도 전주시 덕진구   2589671.0
# 2   201806  전라북도 전주시 덕진구   2547539.0
# 3   201807  전라북도 전주시 덕진구   2966104.0
# 4   201808  전라북도 전주시 덕진구   2759204.0
# 5   201811  전라북도 전주시 덕진구   2665216.0
# 6   201801  전라북도 전주시 덕진구   2500249.0
# 7   201803  전라북도 전주시 덕진구   3170805.0
# 8   201809  전라북도 전주시 덕진구   3181621.0
# 9   201810  전라북도 전주시 덕진구   2852906.0
# 10  201812  전라북도 전주시 덕진구   2711820.0
# 11  201805  전라북도 전주시 덕진구   2815341.0
#       기준연월            지역명      방문자 수
# 0   201901  전라북도 전주시 덕진구   2605631.0
# 1   201903  전라북도 전주시 덕진구   3302737.0
# 2   201904  전라북도 전주시 덕진구   2593636.0
# 3   201905  전라북도 전주시 덕진구   2835227.0
# 4   201906  전라북도 전주시 덕진구   2510542.0
# 5   201907  전라북도 전주시 덕진구   2765022.0
# 6   201909  전라북도 전주시 덕진구   3106533.0
# 7   201910  전라북도 전주시 덕진구   2921470.0
# 8   201912  전라북도 전주시 덕진구   2855806.0
# 9   201902  전라북도 전주시 덕진구   2707947.0
# 10  201908  전라북도 전주시 덕진구   2821890.0
# ...
